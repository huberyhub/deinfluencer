# %% [markdown]
# # Regular Algorithm with Linear Cost

# %%
import sys
sys.path.append('../src')
import networkx as nx
import exp_env as env
import copy

# %%
#G = nx.barabasi_albert_graph(2000, 5)
# link = 5 might yield a result that is quite different
G = nx.barabasi_albert_graph(2000, 2)

# %%
model = env.run_influence_cascade(G, num_influencers=20, steps=3, selection_method='random')

# Evaluate the influence and deinfluence
num_influenced = model.evaluate_influence()
num_deinfluenced = model.evaluate_deinfluence()
num_susceptible = model.evaluate_susceptible()
2
# Create a deep copy of the model
model_fixed_influencers = copy.deepcopy(model)

# Evaluate the influence and deinfluence
num_influenced = model_fixed_influencers.evaluate_influence()
num_deinfluenced = model_fixed_influencers.evaluate_deinfluence()
num_susceptible = model_fixed_influencers.evaluate_susceptible()

print(f"Number of influenced nodes: {num_influenced}")
print(f"Number of deinfluenced nodes: {num_deinfluenced}")
print(f"Number of susceptible nodes: {num_susceptible}")
print('influencer', model.selected_influencers)
# Out:
# Number of influenced nodes: 56
# Number of deinfluenced nodes: 0
# Number of susceptible nodes: 1944
# influencer {284, 542, 1567, 1063, 174, 1711, 1455, 815, 1464, 1859, 457, 458, 207, 1750, 226, 1123, 870, 1395, 373, 1279}

# %% [markdown]
# ### Cascade Step = 2

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=2)
env.plot_deinfluencer_results_exp2(results, G)

# %% [markdown]
# ### Cascade Step = 3

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
env.plot_deinfluencer_results_exp2(results, G)

# %% [markdown]
# ### Cascade step = 4

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=4)
env.plot_deinfluencer_results_exp2(results, G)

# %% [markdown]
# ## Having Larger Budget
# ### Cascade step = 3

# %%
budget_list = list(range(1, 1001, 5))
deinfluencers_list = env.select_deinfluencers_budget(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
env.plot_deinfluencer_results_exp2(results, G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 budget_list = list(range(1, 1001, 5))
#       2 deinfluencers_list = env.select_deinfluencers_budget(budget_list, model_fixed_influencers,'budget_linear')
# ----> 3 results = env.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
#       4 env.plot_deinfluencer_results_exp2(results, G)
#
# File ~/Desktop/Complex Systems 2025/deinfluencer/tests-budget/../src/exp_env.py:151, in average_results_simple(deinfluencers_list, model, num_runs, steps)
#     149 for _ in range(num_runs):
#     150     shuffled_deinfluencers_methods = {method: shuffle_deinfluencers(model, k, deinfluencers) if method in ['Random','High Degree', 'Low Degree'] else deinfluencers for method, deinfluencers in deinfluencers_methods.items()}
# --> 151     results = {
#     152         method: count_deinfluenced(model, deinfluencers, num_runs, steps)
#     153         for method, deinfluencers in shuffled_deinfluencers_methods.items()
#     154     }
#     156     for method, result in results.items():
#     157         cumulative_results[k][method] = (
#     158             cumulative_results[k][method][0] + result[0],
#     159             cumulative_results[k][method][1] + result[1],
#     160             {key: cumulative_results[k][method][2][key] + result[2][key] for key in result[2]}
#     161         )
#
# File ~/Desktop/Complex Systems 2025/deinfluencer/tests-budget/../src/exp_env.py:152, in <dictcomp>(.0)
#     149 for _ in range(num_runs):
#     150     shuffled_deinfluencers_methods = {method: shuffle_deinfluencers(model, k, deinfluencers) if method in ['Random','High Degree', 'Low Degree'] else deinfluencers for method, deinfluencers in deinfluencers_methods.items()}
#     151     results = {
# --> 152         method: count_deinfluenced(model, deinfluencers, num_runs, steps)
#     153         for method, deinfluencers in shuffled_deinfluencers_methods.items()
#     154     }
#     156     for method, result in results.items():
#     157         cumulative_results[k][method] = (
#     158             cumulative_results[k][method][0] + result[0],
#     159             cumulative_results[k][method][1] + result[1],
#     160             {key: cumulative_results[k][method][2][key] + result[2][key] for key in result[2]}
#     161         )
#
# File ~/Desktop/Complex Systems 2025/deinfluencer/tests-budget/../src/exp_env.py:94, in count_deinfluenced(model, deinfluencers, num_runs, steps)
#      90 initial_model = copy.deepcopy(model)
#      92 for _ in range(num_runs):
#      93     # Reset the model to the initial state with the same influencers
# ---> 94     model = copy.deepcopy(initial_model)
#      95     model.reset_transition_counts()
#      96     model.set_deinfluencers(deinfluencers)
#
# File /opt/anaconda3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/anaconda3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/anaconda3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/anaconda3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/anaconda3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/anaconda3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/anaconda3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (1 times), deepcopy at line 146 (1 times)]
#
# File /opt/anaconda3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/anaconda3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/anaconda3/lib/python3.11/copy.py:138, in deepcopy(x, memo, _nil)
#     135     memo = {}
#     137 d = id(x)
# --> 138 y = memo.get(d, _nil)
#     139 if y is not _nil:
#     140     return y
#
# KeyboardInterrupt:

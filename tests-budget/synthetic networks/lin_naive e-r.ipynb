# %% [markdown]
# # Naive Algorithm with Linear Cost

# %%
import sys
sys.path.append('../../src')
import networkx as nx
import exp_env as env
import copy

# %%
# generate a random graph
# can also just load a graph from a file
G = nx.gnm_random_graph(2000, 4000)

# %%
model = env.run_influence_cascade(G, num_influencers=20, steps=3, selection_method='random')

# Evaluate the influence and deinfluence
num_influenced = model.evaluate_influence()
num_deinfluenced = model.evaluate_deinfluence()
num_susceptible = model.evaluate_susceptible()

# Create a deep copy of the model
model_fixed_influencers = copy.deepcopy(model)

# Evaluate the influence and deinfluence
num_influenced = model_fixed_influencers.evaluate_influence()
num_deinfluenced = model_fixed_influencers.evaluate_deinfluence()
num_susceptible = model_fixed_influencers.evaluate_susceptible()

print(f"Number of influenced nodes: {num_influenced}")
print(f"Number of deinfluenced nodes: {num_deinfluenced}")
print(f"Number of susceptible nodes: {num_susceptible}")
print('influencer', model.selected_influencers)
# Out:
# Number of influenced nodes: 300
# Number of deinfluenced nodes: 0
# Number of susceptible nodes: 1700
# influencer {2, 268, 1307, 1182, 1823, 1956, 1582, 1077, 822, 1978, 458, 1226, 338, 599, 472, 1762, 227, 1388, 1904, 882}

# %% [markdown]
# ### Cascade Step = 2

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_budget(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=2)
env.plot_deinfluencer_results_budget(results, G)

# %% [markdown]
# ### Cascade Step = 3

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_budget(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
env.plot_deinfluencer_results_budget(results, G)

# %% [markdown]
# ### Cascade step = 4

# %%
budget_list = list(range(1, 201))
deinfluencers_list = env.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_budget(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=4)
env.plot_deinfluencer_results_budget(results, G)

# %% [markdown]
# ## Having Larger Budget
# ### Cascade step = 3

# %%
budget_list = list(range(1, 1001, 5))
deinfluencers_list = env.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = env.average_results_budget(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
env.plot_deinfluencer_results_budget(results, G)
